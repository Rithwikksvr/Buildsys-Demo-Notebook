# %%
import warnings
warnings.filterwarnings("ignore")
warnings.filterwarnings("ignore")

# %%
from nilmtk.api import API

# %%
from nilmtk.disaggregate import Mean, FHMMExact

# %%
redd = {
  'power': {
    'mains': ['apparent','active'],
    'appliance': ['apparent','active']
  },
  'sample_rate': 60,
    
  'artificial_aggregate':True,
  'appliances': ['fridge','air conditioner'],
  'methods': {
      'FHMMExact':FHMMExact({'num_of_states':2}),
      
      'Mean': Mean({}),
      
          
  },
   'train': {    
    'datasets': {
            'Dataport': {
                'path': 'C:/Users/Hp/Desktop/nilmtk-contrib/dataport.hdf5',
				'buildings': {
				10: {
					'start_time': '2015-04-04',
					'end_time': '2015-04-15'
				}
				}
				                
			}
			}
	},
	'test': {
	'datasets': {
		'Datport': {
			'path': 'C:/Users/Hp/Desktop/nilmtk-contrib/dataport.hdf5',
			'buildings': {
				10: {
					'start_time': '2015-04-16',
					'end_time': '2015-04-18'
				},
			}
	}
},
        'metrics':['mae','rmse']
}
}

# %%
api_results = API(redd)
# Out:
# Joint Testing for all algorithms
# Loading data for  Datport  dataset
# Dropping missing values
# Creating an Artificial Aggregate
# Generating predictions for : FHMM
# Generating predictions for : Mean
# ............  mae  ..............
#                  FHMMExact       Mean
# fridge            5.642014   46.14151
# air conditioner   7.928820  194.96463
# ............  rmse  ..............
#                  FHMMExact        Mean
# fridge           28.203754   56.881932
# air conditioner  35.987213  296.905525

# %%
errors_keys = api_results.errors_keys
errors = api_results.errors
for i in range(len(errors)):
    print (errors_keys[i])
    print (errors[i])
    print ("\n\n")
# Out:
# Datport_10_mae
#                  FHMMExact       Mean
# fridge            5.642014   46.14151
# air conditioner   7.928820  194.96463
#
#
#
# Datport_10_rmse
#                  FHMMExact        Mean
# fridge           28.203754   56.881932
# air conditioner  35.987213  296.905525

# %%
from nilmtk_contrib.disaggregate import DAE
# Out:
# Using TensorFlow backend.

# %%
redd = {
  'power': {
    'mains': ['apparent','active'],
    'appliance': ['apparent','active']
  },
  'sample_rate': 60,
    
  'artificial_aggregate':True,
  'appliances': ['fridge','air conditioner'],
  'methods': {
      
      
      'Mean': Mean({}),
      'DAE':DAE({'n_epochs':100,'pretrained-model-path':'buildsys-dae'})
          
  },
   'train': {    
    'datasets': {
            'Dataport': {
                'path': 'C:/Users/Hp/Desktop/nilmtk-contrib/dataport.hdf5',
				'buildings': {
				10: {
					'start_time': '2015-04-04',
					'end_time': '2015-04-15'
				}
				}
				                
			}
			}
	},
	'test': {
	'datasets': {
		'Datport': {
			'path': 'C:/Users/Hp/Desktop/nilmtk-contrib/dataport.hdf5',
			'buildings': {
				10: {
					'start_time': '2015-04-16',
					'end_time': '2015-04-18'
				},
			}
	}
},
        'metrics':['mae','rmse']
}
}
# Out:
# Loading the model using the pretrained-weights
# WARNING:tensorflow:From C:\Users\Hp\Anaconda3\envs\new_niltmk_env_testing\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
api_results = API(redd)
# Out:
# Started training for  DAE
# DAE  is loading the pretrained model
# Joint Testing for all algorithms
# Loading data for  Datport  dataset
# Dropping missing values
# Creating an Artificial Aggregate
# Generating predictions for : Mean
# Generating predictions for : DAE
# ............  mae  ..............
#                       Mean        DAE
# fridge            46.14151  17.382490
# air conditioner  194.96463  17.388744
# ............  rmse  ..............
#                        Mean        DAE
# fridge            56.881932  35.802268
# air conditioner  296.905525  56.501041

# %%
errors_keys = api_results.errors_keys
errors = api_results.errors
for i in range(len(errors)):
    print (errors_keys[i])
    print (errors[i])
    print ("\n\n")
# Out:
# Datport_10_mae
#                       Mean        DAE
# fridge            46.14151  17.382490
# air conditioner  194.96463  17.388744
#
#
#
# Datport_10_rmse
#                        Mean        DAE
# fridge            56.881932  35.802268
# air conditioner  296.905525  56.501041
